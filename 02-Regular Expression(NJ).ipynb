# %%
text = "the agent's phone number is 408-555-1234. call soon!"

# %% [markdown]
# checking value phone is in text or not

# %%
"phone" in text
# Out:
# True

# %%
import re

# %%
pattern ="phone"
re.search(pattern , text)
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
pattern = "not in text"
re.search(pattern,text)

# %%
pattern ="phone"
matcher = re.search(pattern , text)

# %% [markdown]
# if pattern is in text its give index , else its just run not giving output

# %%
print(matcher.span())
print(matcher.start())
print(matcher.end())
# Out:
# (3, 8)
# 3
# 8

# %%
text= "my phone is new phone"
match = re.search("phone",text)

# %%
match
# Out:
# <re.Match object; span=(3, 8), match='phone'>

# %%
match.span()
# Out:
# (3, 8)

# %% [markdown]
# finding all the matchers

# %%
matches = re.findall("phone" , text)
matches
# Out:
# ['phone', 'phone']

# %%
len(matches)
# Out:
# 2

# %%
for match in re.finditer("phone",text):
    print(match.span())
# Out:
# (3, 8)
# (16, 21)

# %% [markdown]
# #to find the pattern

# %%
text = "my phone number is 408-555-1234"

# %%
phone = re.search(r'\d\d\d-' , text)
phone.group()
# Out:
# '408-'

# %%
for phone in re.finditer(r'\d\d\d-' , text):
    print(phone.group())
# Out:
# 408-
# 555-

# %%
#grouping of the text like addhrcar

# %%
phone_pp = re.compile(r'(\d{3})-(\d{3})-(\d{4})')
re.search(phone_pp,text).group()
# Out:
# '408-555-1234'

# %%
print(re.search(phone_pp,text).group(1))
print(re.search(phone_pp,text).group(2))
print(re.search(phone_pp,text).group(3))
# Out:
# 408
# 555
# 1234

# %%
phone_pp = re.compile(r'(\d{3})-')
re.search(phone_pp,text).group()
# Out:
# '408-'

# %%
print(re.search(phone_pp,text).group(1))
print(re.search(phone_pp,text).group(2))
print(re.search(phone_pp,text).group(3))
#its give me eeror to not that pattren
# Out:
# 408
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 print(re.search(phone_pp,text).group(1))
# ----> 2 print(re.search(phone_pp,text).group(2))
#       3 print(re.search(phone_pp,text).group(3))
#       4 #its give me eeror to not that pattren
#
# IndexError: no such group

# %%
##or opreator |

# %%
re.search(r'man|women' , 'this women was here ')
# Out:
# <re.Match object; span=(5, 10), match='women'>

# %%
re.search(r'man|women' , 'this kartik is here ')

# %%
re.findall(r'.at' , 'the cat in the hat sat here')
# Out:
# ['cat', 'hat', 'sat']

# %%
re.findall(r'.at' , 'the bat went splat')
# Out:
# ['bat', 'lat']

# %%
re.findall(r'...at' , 'the bat went splat')
# Out:
# ['e bat', 'splat']

# %%
re.findall(r'\S+at' , 'the bat went splat')
# Out:
# ['bat', 'splat']

# %% [markdown]
# #start with and end with

# %%
re.findall(r'\d$' , '1 this end with a number 290')
# its give me last word
# Out:
# ['0']

# %%
re.findall(r'^\d' , '1 this start with a number 2 ')
# its give me first word
# Out:
# ['1']

# %% [markdown]
# #exclusion

# %% [markdown]
# to eclude char , we can use the ^ symbol is conjunction with a set of brackets [] . anything inside thr [] , is excluded

# %%
pharse =" therr are 3 number 34 inside 5 this sentence "

# %%
re.findall(r'[^\d]' , pharse)
# Out:
# [' ',
#  't',
#  'h',
#  'e',
#  'r',
#  'r',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  ' ',
#  'n',
#  'u',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ',
#  ' ',
#  'i',
#  'n',
#  's',
#  'i',
#  'd',
#  'e',
#  ' ',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  's',
#  'e',
#  'n',
#  't',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ']

# %%
re.findall(r'[^\d]+' , pharse)
# Out:
# [' therr are ', ' number ', ' inside ', ' this sentence ']

# %%
test_phrse = ' this is a string ! but it has punctuation . how can we remove it?'

# %%
re.findall(r'[^!.? ]+' , test_phrse)
# Out:
# ['this',
#  'is',
#  'a',
#  'string',
#  'but',
#  'it',
#  'has',
#  'punctuation',
#  'how',
#  'can',
#  'we',
#  'remove',
#  'it']

# %%
re.findall(r'[^!.?]+' , test_phrse)
# Out:
# [' this is a string ', ' but it has punctuation ', ' how can we remove it']

# %%
clean = " ".join(re.findall(r'[^!.? ]+' , test_phrse))
clean
# Out:
# 'this is a string but it has punctuation how can we remove it'

# %%
clean
# Out:
# 'this is a string but it has punctuation how can we remove it'

# %% [markdown]
# brackets for grouping

# %%
text = "only find the hypen-word in this sentence. but you do not know how long-ish they are"

# %%
re.findall(r'[\w]+-[\w]+', text)
# Out:
# ['hypen-word', 'long-ish']
